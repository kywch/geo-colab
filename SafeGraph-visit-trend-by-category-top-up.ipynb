# %% [markdown]
# <a href="https://colab.research.google.com/github/kywch/geo-colab/blob/master/SafeGraph-visit-trend-by-category-top-up.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import gzip as gz
import os
from pathlib import Path
import json
import matplotlib.pyplot as plt

from glob import glob
import time

import os
from shutil import copyfile, copytree

# %% [markdown]
# ## Load the SafeGraph data from Google Drive
# Load visit patterns from march-june 2019 for the desired place types, keep places that have data for entire march-june range
# * places
# * cbg_pop
# * patterns_2019

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive/SafeGraph
# Out:
#  census_vs_safegraph_IL.csv   'Places Schema.url'
#  daily_visits_2019.csv	       places_v3_safegraph.csv
#  daily_visits_2019_ext.csv     safegraph_panel
#  daily_visits_2020.csv	       social-distancing
#  daily_visits_2020_ext.csv     summ_by_naics_2digits.csv
# 'Data Science Resources.url'   summ_by_naics_3digits.csv
#  historic		       summ_by_naics_3digits.xlsx
# 'INRIX DATA.zip'	       vis_2020
#  monthly		       weekly
#  patterns_covid.csv.gz	      'Weekly Patterns.url'
#  Patterns_NE-IL_2019.csv.gz    weekly_v2
#  places

# %%
# grab the SafeGraph core places
files = glob("drive/My Drive/SafeGraph/*.csv*")
print(files)
# Out:
# ['drive/My Drive/SafeGraph/places_v3_safegraph.csv', 'drive/My Drive/SafeGraph/census_vs_safegraph_IL.csv', 'drive/My Drive/SafeGraph/Patterns_NE-IL_2019.csv.gz', 'drive/My Drive/SafeGraph/daily_visits_2019.csv', 'drive/My Drive/SafeGraph/daily_visits_2020.csv', 'drive/My Drive/SafeGraph/patterns_covid.csv.gz', 'drive/My Drive/SafeGraph/daily_visits_2019_ext.csv', 'drive/My Drive/SafeGraph/daily_visits_2020_ext.csv', 'drive/My Drive/SafeGraph/summ_by_naics_2digits.csv', 'drive/My Drive/SafeGraph/summ_by_naics_3digits.csv']

# %%
if not os.path.exists('sg_data'):
  os.mkdir('sg_data')

# %%
# copy these files from Google Drive to colab disk
for f in files:
  print(f)
  copyfile(f, 'sg_data/' + os.path.basename(f))
# Out:
# drive/My Drive/SafeGraph/places_v3_safegraph.csv
# drive/My Drive/SafeGraph/census_vs_safegraph_IL.csv
# drive/My Drive/SafeGraph/Patterns_NE-IL_2019.csv.gz
# drive/My Drive/SafeGraph/daily_visits_2019.csv
# drive/My Drive/SafeGraph/daily_visits_2020.csv
# drive/My Drive/SafeGraph/patterns_covid.csv.gz
# drive/My Drive/SafeGraph/daily_visits_2019_ext.csv
# drive/My Drive/SafeGraph/daily_visits_2020_ext.csv
# drive/My Drive/SafeGraph/summ_by_naics_2digits.csv
# drive/My Drive/SafeGraph/summ_by_naics_3digits.csv

# %%
#!ls sg_data
local_files = glob("sg_data/*.csv*")
print(local_files)
# Out:
# ['sg_data/daily_visits_2020_ext.csv', 'sg_data/summ_by_naics_3digits.csv', 'sg_data/patterns_covid.csv.gz', 'sg_data/places_v3_safegraph.csv', 'sg_data/daily_visits_2019.csv', 'sg_data/daily_visits_2020.csv', 'sg_data/summ_by_naics_2digits.csv', 'sg_data/daily_visits_2019_ext.csv', 'sg_data/census_vs_safegraph_IL.csv', 'sg_data/Patterns_NE-IL_2019.csv.gz']

# %%
place_df = pd.read_csv('sg_data/places_v3_safegraph.csv')
place_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74782 entries, 0 to 74781
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   numeric_id          74782 non-null  int64
#  1   place_id            74782 non-null  object
#  2   place_type          74782 non-null  object
#  3   latitude            74782 non-null  float64
#  4   longitude           74782 non-null  float64
#  5   name                74782 non-null  object
#  6   zipcode             74782 non-null  int64
#  7   visits_IL           64394 non-null  float64
#  8   unique_visitors_IL  64394 non-null  float64
#  9   cbg                 74782 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 5.7+ MB

# %%
place_types = [key for key in place_df['place_type'].value_counts().keys()]
place_types
# Out:
# ['restaurant',
#  'clinic',
#  'recreation',
#  'store',
#  'worship',
#  'pharmacy',
#  'daycare',
#  'supermarket',
#  'convenience store',
#  'long term care',
#  'library',
#  'bar',
#  'museum',
#  'hospital']

# %%
# Exrtact desired place types from v3 safegraph places file (7 county area)
places = place_df[['place_id', 'place_type']]

# %%
# Load cbg population vs safegraph devices
cbg_pop = pd.read_csv('sg_data/census_vs_safegraph_IL.csv') # https://anl.box.com/s/k2e7e833gfekqsihaachbj9pfsshhc2g
cbg_pop = cbg_pop[cbg_pop['state'] == 'IL'] # base table has a few non-IL cbgs
print("Number of IL cbgs (should be 9691): {}".format(len(cbg_pop)))
# Out:
# Number of IL cbgs (should be 9691): 9691

# %%
# load 2019 patterns
patterns_2019 = pd.read_csv('sg_data/Patterns_NE-IL_2019.csv.gz') # https://anl.box.com/s/zf3xt1cbd6vjs40e9njw91jm1jgkxj83

# %%
len(patterns_2019)
# Out:
# 1233810

# %%
patterns_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1233810 entries, 0 to 1233809
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   safegraph_place_id         1233810 non-null  object
#  1   location_name              1233810 non-null  object
#  2   street_address             1233810 non-null  object
#  3   city                       1233810 non-null  object
#  4   postal_code                1233810 non-null  int64
#  5   safegraph_brand_ids        278242 non-null   object
#  6   brands                     278242 non-null   object
#  7   date_range_start           1233810 non-null  object
#  8   date_range_end             1233810 non-null  object
#  9   raw_visit_counts           1233810 non-null  int64
#  10  raw_visitor_counts         1233810 non-null  int64
#  11  visits_by_day              1233810 non-null  object
#  12  poi_cbg                    1233798 non-null  float64
#  13  visitor_home_cbgs          1233810 non-null  object
#  14  visitor_daytime_cbgs       1233810 non-null  object
#  15  visitor_work_cbgs          1233810 non-null  object
#  16  visitor_country_of_origin  1230123 non-null  object
#  17  distance_from_home         1087467 non-null  float64
#  18  median_dwell               1233810 non-null  float64
#  19  bucketed_dwell_times       1233810 non-null  object
#  20  related_same_day_brand     1233810 non-null  object
#  21  related_same_month_brand   1233810 non-null  object
#  22  popularity_by_hour         1233810 non-null  object
#  23  popularity_by_day          1233810 non-null  object
#  24  device_type                1233810 non-null  object
# dtypes: float64(3), int64(3), object(19)
# memory usage: 235.3+ MB

# %%
# keep patterns for the selected place types only
patterns_2019 = patterns_2019.merge(places, how='left', left_on = 'safegraph_place_id', right_on = 'place_id')

# %%
# add the other category
patterns_2019['place_type'][patterns_2019['place_type'].isnull()] = 'other'
patterns_2019['place_type'].value_counts()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# other                502848
# restaurant           233574
# clinic               151058
# recreation            99965
# store                 93929
# worship               45335
# pharmacy              32336
# daycare               28290
# supermarket           25550
# convenience store      6356
# long term care         4831
# library                3700
# bar                    2928
# museum                 1927
# hospital               1183
# Name: place_type, dtype: int64

# %%
#months = [3, 4, 5, 6, 7, 8] # march-august

# top-up September
months = [9] 

# extract month from safegraph date range 
def get_month(date):
    ymd = date.split('-')
    day = int(ymd[2].split('T')[0])
    if day != 1:
        print('date range not starting with 1st of month')
    return int(ymd[1]) # month

# %%
patterns_2019['month'] = patterns_2019['date_range_start'].apply(get_month)
# keep only march-june patterns
patterns_2019 = patterns_2019[patterns_2019['month'].isin(months)]
#keep only for places that have data for entire march-june period
counts = patterns_2019.groupby('safegraph_place_id').count()
counts = counts[counts['month'] == len(months)]
patterns_2019_flt = patterns_2019[patterns_2019['safegraph_place_id'].isin(counts.index)]

# %%
len(patterns_2019_flt)
# Out:
# 102971

# %%
patterns_2019_flt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102971 entries, 8 to 1232974
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   safegraph_place_id         102971 non-null  object
#  1   location_name              102971 non-null  object
#  2   street_address             102971 non-null  object
#  3   city                       102971 non-null  object
#  4   postal_code                102971 non-null  int64
#  5   safegraph_brand_ids        23181 non-null   object
#  6   brands                     23181 non-null   object
#  7   date_range_start           102971 non-null  object
#  8   date_range_end             102971 non-null  object
#  9   raw_visit_counts           102971 non-null  int64
#  10  raw_visitor_counts         102971 non-null  int64
#  11  visits_by_day              102971 non-null  object
#  12  poi_cbg                    102970 non-null  float64
#  13  visitor_home_cbgs          102971 non-null  object
#  14  visitor_daytime_cbgs       102971 non-null  object
#  15  visitor_work_cbgs          102971 non-null  object
#  16  visitor_country_of_origin  102635 non-null  object
#  17  distance_from_home         91157 non-null   float64
#  18  median_dwell               102971 non-null  float64
#  19  bucketed_dwell_times       102971 non-null  object
#  20  related_same_day_brand     102971 non-null  object
#  21  related_same_month_brand   102971 non-null  object
#  22  popularity_by_hour         102971 non-null  object
#  23  popularity_by_day          102971 non-null  object
#  24  device_type                102971 non-null  object
#  25  place_id                   60929 non-null   object
#  26  place_type                 102971 non-null  object
#  27  month                      102971 non-null  int64
# dtypes: float64(3), int64(4), object(21)
# memory usage: 22.8+ MB

# %%
# generate the extended places
places_ext = patterns_2019_flt[['safegraph_place_id', 'place_type']].drop_duplicates(ignore_index=True)

# %%
places_ext['place_type'].value_counts()
# Out:
# other                42042
# restaurant           19470
# clinic               12585
# recreation            8324
# store                 7829
# worship               3797
# pharmacy              2697
# daycare               2356
# supermarket           2129
# convenience store      530
# long term care         403
# library                305
# bar                    244
# museum                 161
# hospital                99
# Name: place_type, dtype: int64

# %% [markdown]
# # Do the same for march-june 2020 visit patterns

# %%
# monthly patterns file in the Google drive

top_up_month = '09'

print(glob("drive/My Drive/SafeGraph/vis_2020/" + top_up_month + "/*.csv.gz"))
# Out:
# ['drive/My Drive/SafeGraph/vis_2020/09/patterns-part1.csv.gz', 'drive/My Drive/SafeGraph/vis_2020/09/patterns-part4.csv.gz', 'drive/My Drive/SafeGraph/vis_2020/09/patterns-part2.csv.gz', 'drive/My Drive/SafeGraph/vis_2020/09/patterns-part3.csv.gz']

# %%
flag_process_2020 = True

#if os.path.exists('sg_data/patterns_covid.csv.gz'):
#  flag_process_2020 = False
#  patterns_2020_flt = pd.read_csv('sg_data/patterns_covid.csv.gz')

# %%
if (flag_process_2020):
  copytree("drive/My Drive/SafeGraph/vis_2020/" + top_up_month, "vis_2020")

# !ls vis_2020
# Out:
# patterns-part1.csv.gz  patterns-part3.csv.gz
# patterns-part2.csv.gz  patterns-part4.csv.gz

# %%
if (flag_process_2020):
  # This code directly extracts data from raw .csv.gz patterns files, for the place types defined at the beginning
  # Download files from here- https://catalog.safegraph.io/app/browse
  #   From Monthly Patterns Jan 2018 - Apr 2020: download subfolders 2020/03 and 2020/04
  #   From Montnly Patterns May 2020- Present: download everything (confusing folder structure, couldn't isolate may and june)
  # Dump all the files in one folder and set the path accordingly on the line below
  rootdir = Path('vis_2020')

  # Return a list of regular files only, not directories
  file_list = [f for f in rootdir.glob('**/*.csv.gz') if f.is_file()]
  #print(file_list)

  patterns_2020 = pd.DataFrame()

  for fl in file_list:
      print(fl)
      part = pd.read_csv(fl)
      
      # keep patterns for the selected place types only
      part = part.merge(places_ext, left_on = 'safegraph_place_id', right_on = 'safegraph_place_id')
      part['month'] = part['date_range_start'].apply(get_month)
      # keep only march-june patterns
      part = part[part['month'].isin(months)]

      patterns_2020 = patterns_2020.append(part)

  #keep only for places that have data for entire march-june period
  counts = patterns_2020.groupby('safegraph_place_id').count()
  counts = counts[counts['month'] == len(months)]
  patterns_2020_flt = patterns_2020[patterns_2020['safegraph_place_id'].isin(counts.index)]
# Out:
# vis_2020/patterns-part4.csv.gz
# vis_2020/patterns-part2.csv.gz
# vis_2020/patterns-part1.csv.gz
# vis_2020/patterns-part3.csv.gz

# %%
print('2019: ', len(patterns_2019_flt))
print('2020: ', len(patterns_2020_flt))
# Out:
# 2019:  102971
# 2020:  87845

# %% [markdown]
# # Compute daily visitor counts for march-june 2019 and 2020

# %%
# look only at places that have complete data for both 2019 and 2020
patterns_2019 = patterns_2019_flt[patterns_2019_flt['safegraph_place_id'].isin(patterns_2020_flt['safegraph_place_id'])]
patterns_2020 = patterns_2020_flt[patterns_2020_flt['safegraph_place_id'].isin(patterns_2019_flt['safegraph_place_id'])]

# %%
print('Should be the same -- 2019:', len(patterns_2019), ' vs. 2020:', len(patterns_2020))
# Out:
# Should be the same -- 2019: 87845  vs. 2020: 87845

# %%
# !rm -rf safegraph_panel/
copytree("drive/My Drive/SafeGraph/safegraph_panel", "safegraph_panel")
# !ls safegraph_panel
# Out:
# 2019-03-18-home-panel-summary.csv  2019-12-16-home-panel-summary.csv
# 2019-04-15-home-panel-summary.csv  2020-03-16-home-panel-summary.csv
# 2019-05-13-home-panel-summary.csv  2020-04-13-home-panel-summary.csv
# 2019-06-17-home-panel-summary.csv  2020-05-18-home-panel-summary.csv
# 2019-07-15-home-panel-summary.csv  2020-06-08-home-panel-summary.csv
# 2019-08-19-home-panel-summary.csv  2020-07-15-home_panel_summary.csv
# 2019-09-16-home-panel-summary.csv  2020-08-19-home_panel_summary.csv
# 2019-10-14-home-panel-summary.csv  2020-09-16-home_panel_summary.csv
# 2019-11-18-home-panel-summary.csv

# %%
print('Top up month:', months)
glob("safegraph_panel/20*-" + str(months[0]).zfill(2) + "*")
# Out:
# Top up month: [9]
# ['safegraph_panel/2019-09-16-home-panel-summary.csv',
#  'safegraph_panel/2020-09-16-home_panel_summary.csv']

# %%
# Extract Safegraph mobile device counts per cbg for the relevant months (march-june 2019, march-june 2020)
# Files here: https://anl.box.com/s/c9ts8tks1sbiak0mjooska0aa40rbaf0
#   originally taken from Safegraph home panel summarry: https://catalog.safegraph.io/app/browse, under "Weekly Patterns v2", subfolder v2/home-summary/file
cbg_pop = cbg_pop[['census_block_group', 'census_population', 'county']]

for year in [2019, 2020]:
    for month in months:
        file = glob('safegraph_panel/' + str(year) + '-' + str(month).zfill(2) + '*.csv')
        part = pd.read_csv(file[0])
        ym = str(year) + '-' + str(month).zfill(2)
        part[ym] = part['number_devices_residing']
        part = part[['census_block_group', ym]]
        cbg_pop = cbg_pop.merge(part, on = 'census_block_group', how = 'left')

# %%
print(cbg_pop.info())
cbg_pop2 = cbg_pop.dropna()
print(cbg_pop2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9691 entries, 0 to 9690
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   census_block_group  9691 non-null   int64
#  1   census_population   9691 non-null   int64
#  2   county              9691 non-null   object
#  3   2019-09             9690 non-null   float64
#  4   2020-09             9689 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 454.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9688 entries, 0 to 9690
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   census_block_group  9688 non-null   int64
#  1   census_population   9688 non-null   int64
#  2   county              9688 non-null   object
#  3   2019-09             9688 non-null   float64
#  4   2020-09             9688 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 454.1+ KB
# None

# %%
# compute true population / safegraph devices ratio for each month
for month in months:
    for year in ['2019-', '2020-']:
        col = year + str(month).zfill(2)
        cbg_pop2[col] = cbg_pop2['census_population'] / cbg_pop2[col]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#patterns_2019.head()
place_types = [key for key in places_ext['place_type'].value_counts().keys()]
print(place_types)
# Out:
# ['other', 'restaurant', 'clinic', 'recreation', 'store', 'worship', 'pharmacy', 'daycare', 'supermarket', 'convenience store', 'long term care', 'library', 'bar', 'museum', 'hospital']

# %%
# compute daily visits for march-june of given year
def get_daily_visits(patterns, year):
    gmonth = patterns.groupby('month')
    daily_visits = {}
    # output structure: for each place type, array of daily total visitor counts
    # e.g. daily_visits['restaurant'][i] = x means x total visitors to restaurants on day i, with day 0 being March 1st
    
    for month in months:
        month_visits = {}
        print("month {}".format(month))
        subset = gmonth.get_group(month)

        # extract census pop/safegraph devices ratio for the relevant month and year
        month_col = year + '-' + str(month).zfill(2)
        cbg_ratio = pd.Series(cbg_pop2[month_col].values, index = cbg_pop2['census_block_group'].values)
        cbg_ratio = cbg_ratio.to_dict()

        for ind, row in subset.iterrows():
            visitor_counts = json.loads(row.visitor_home_cbgs)
            total_cbg = 0 # count total number of visitors by cbg
            for cbg, nvis in visitor_counts.items():
                total_cbg += nvis

            # cbg-level uncertainty: visitor counts of 2-4 from a cbg are always reported as 4
            # adding up visitors from all origin cbgs is not consistent with a place's raw_visitor_counts
            # so proportionally distribute raw_visitor_counts to its cbgs rather than keeping original reported values
            total_true_IL = 0
            for cbg, nvis in visitor_counts.items():
                if int(cbg) in cbg_ratio: # keep only visitors from IL cbgs
                    vis_proportion = row.raw_visitor_counts * (nvis / total_cbg)
                    # multiply by ratio of true census population over number of
                    # safegraph devices tracked in the respective month
                    true_vis = vis_proportion * cbg_ratio[int(cbg)]

                    total_true_IL += true_vis

            # now proportionally distribute the IL visitors as per visits_by_day
            vis_by_day = json.loads(row.visits_by_day)
            ndays = len(vis_by_day)
            vis_sum = sum(vis_by_day)
            for i in range(ndays):
                vis_by_day[i] = round((vis_by_day[i] / vis_sum) * total_true_IL)

            # add daily visit counts to place totals for the current month
            if row.place_type in month_visits:
                month_visits[row.place_type] = np.add(month_visits[row.place_type], np.array(vis_by_day))
            else:
                month_visits[row.place_type] = np.array(vis_by_day)

        # for each place type, append current month visit counts
        for pt in place_types:
            if pt in daily_visits:
                daily_visits[pt] = np.append(daily_visits[pt], month_visits[pt])
            else:
                daily_visits[pt] = month_visits[pt]
    
    return daily_visits

# %%
daily_visits_19 = get_daily_visits(patterns_2019, '2019')
# Out:
# month 9

# %%
daily_visits_19
# Out:
# {'bar': array([20558, 15538, 15817, 17764, 20153, 22795, 30130, 17974, 15956,
#         16919, 17774, 18978, 26271, 32584, 19070, 17026, 17147, 20100,
#         19184, 25428, 29679, 22868, 17530, 17007, 18124, 18139, 22907,
#         26889, 19174, 15256]),
#  'clinic': array([109161, 111710, 279557, 279682, 277647, 264803, 190838, 123709,
#         289837, 289547, 291625, 295400, 268836, 184673, 129827, 288894,
#         289382, 293197, 283775, 266264, 177210, 126138, 279975, 283423,
#         271838, 266140, 239019, 161886, 113585, 262245]),
#  'convenience store': array([34635, 33171, 39342, 40018, 42440, 46734, 48501, 34591, 40322,
#         42244, 44677, 44644, 49286, 48422, 36939, 42412, 41524, 43305,
#         42938, 48087, 43412, 34108, 40430, 40151, 41276, 40543, 43128,
#         40580, 31464, 40782]),
#  'daycare': array([40199, 28345, 67240, 71056, 69891, 67301, 50257, 51252, 68788,
#         71465, 74056, 72462, 71212, 50151, 55188, 70699, 71619, 75276,
#         72344, 71339, 47353, 53323, 67730, 69939, 69802, 67321, 63892,
#         42775, 46264, 61574]),
#  'hospital': array([16890, 18565, 43254, 45413, 43158, 42485, 22523, 19621, 46438,
#         46418, 47044, 46311, 44602, 23929, 20378, 45341, 46476, 48063,
#         45015, 42014, 21984, 18725, 43521, 44479, 43921, 42711, 39522,
#         19927, 16896, 41159]),
#  'library': array([ 8846,  5825, 28675, 29557, 26387, 23278, 21139, 14025, 30045,
#         29737, 32348, 29213, 24188, 18989, 15231, 32210, 32491, 32341,
#         30012, 22348, 19941, 14285, 30578, 30700, 30386, 27620, 20412,
#         18311, 12734, 29505]),
#  'long term care': array([11130, 12261, 16740, 17018, 17855, 17473, 15387, 14293, 17719,
#         19051, 18573, 18441, 18485, 15938, 14933, 17588, 18747, 18535,
#         17556, 17245, 15018, 13497, 16831, 17520, 17155, 16835, 16081,
#         13266, 11815, 15798]),
#  'museum': array([16064, 11179, 15133, 15501, 16034, 16485, 16274, 10629, 14746,
#         15600, 16939, 17037, 16533, 17004, 11505, 16169, 16618, 17733,
#         17093, 17086, 17685, 11242, 14965, 16531, 16227, 14873, 15420,
#         15099, 11259, 13554]),
#  'other': array([2144122, 2021283, 2504549, 2577085, 2619537, 2900619, 2914663,
#         2246530, 2532442, 2616740, 2678232, 2731085, 3028502, 3028331,
#         2275309, 2577355, 2629266, 2697127, 2710480, 3002705, 2866833,
#         2224533, 2543417, 2567797, 2538450, 2548947, 2614178, 2757196,
#         2113812, 2383027]),
#  'pharmacy': array([144525, 132392, 196151, 195629, 194215, 202202, 205954, 160005,
#         193102, 192781, 199386, 200316, 209869, 207765, 161179, 191382,
#         192912, 196301, 195702, 204527, 200266, 151344, 187151, 187124,
#         190476, 189088, 190254, 203028, 153354, 190353]),
#  'recreation': array([550824, 494979, 587588, 630283, 621123, 656879, 797108, 569840,
#         618903, 653598, 679572, 677335, 696927, 802901, 598318, 644438,
#         662142, 681102, 671351, 707906, 757199, 533484, 627757, 643292,
#         631265, 637522, 573759, 636157, 487382, 564945]),
#  'restaurant': array([1964234, 1657859, 1842251, 1955465, 2021026, 2453867, 2674709,
#         1999315, 1856730, 1970873, 2065754, 2152716, 2604604, 2750598,
#         2045599, 1900581, 1984965, 2099936, 2130225, 2605720, 2628721,
#         1990005, 1877148, 1935596, 1957763, 1996877, 2272185, 2484934,
#         1843956, 1764541]),
#  'store': array([ 970631,  875312,  860050,  898453,  891739, 1030035, 1234960,
#         1029236,  874925,  873834,  913123,  930107, 1071100, 1240570,
#         1001016,  887851,  889133,  917034,  921878, 1060884, 1209373,
#          993612,  869074,  858341,  857569,  867809,  910077, 1197674,
#          936917,  816785]),
#  'supermarket': array([342101, 344856, 305423, 302720, 302126, 309972, 375545, 393002,
#         318074, 307404, 308649, 307742, 334617, 372942, 388772, 318648,
#         306902, 307014, 298861, 321186, 363336, 379256, 315695, 290999,
#         284678, 282246, 295518, 356798, 356125, 290529]),
#  'worship': array([152118,  67919,  88362,  99512,  94453, 104041, 126070, 191403,
#          98474, 102868, 116861, 106086, 114616, 131419, 197022,  98648,
#         106244, 117548, 108636, 108230, 127707, 188712,  96004,  99836,
#         106683,  94807,  93910, 108489, 171124,  88824])}

# %%
visit_2019_df = pd.read_csv('drive/My Drive/SafeGraph/daily_visits_2019_ext.csv')
visit_2019_df['date'] = pd.date_range(start='3/1/2019', end='9/30/2019')
visit_2019_df.set_index('date')
print(visit_2019_df)
# Out:
#      Unnamed: 0  Unnamed: 0.1    other  ...  museum  hospital       date
# 0             0           0.0  2565785  ...   13600     37679 2019-03-01
# 1             1           1.0  2512519  ...   12295     20703 2019-03-02
# 2             2           2.0  1939123  ...    8483     18171 2019-03-03
# 3             3           3.0  2191183  ...   11779     44033 2019-03-04
# 4             4           4.0  2240618  ...   13506     44848 2019-03-05
# ..          ...           ...      ...  ...     ...       ...        ...
# 209         209           NaN  2548947  ...   14873     42711 2019-09-26
# 210         210           NaN  2614178  ...   15420     39522 2019-09-27
# 211         211           NaN  2757196  ...   15099     19927 2019-09-28
# 212         212           NaN  2113812  ...   11259     16896 2019-09-29
# 213         213           NaN  2383027  ...   13554     41159 2019-09-30
#
# [214 rows x 18 columns]

# %%
daily_visits_20 = get_daily_visits(patterns_2020, '2020')
# Out:
# month 9

# %%
visit_2020_df = pd.read_csv('drive/My Drive/SafeGraph/daily_visits_2020_ext.csv')
visit_2020_df = pd.concat([visit_2020_df, pd.DataFrame.from_dict(daily_visits_20)], ignore_index=True)
visit_2020_df['date'] = pd.date_range(start='3/1/2020', end='9/30/2020')
print(visit_2020_df)
visit_2020_df.to_csv("drive/My Drive/SafeGraph/daily_visits_2020_ext.csv")
# Out:
#      Unnamed: 0    other  restaurant  ...  museum  hospital       date
# 0           0.0  2885374     2609379  ...   13210     22110 2020-03-01
# 1           1.0  3145776     2248614  ...   18080     53613 2020-03-02
# 2           2.0  3198923     2256875  ...   18967     57642 2020-03-03
# 3           3.0  3067402     2240613  ...   18632     49598 2020-03-04
# 4           4.0  3256324     2422362  ...   20534     50773 2020-03-05
# ..          ...      ...         ...  ...     ...       ...        ...
# 209         NaN  2070318     1802283  ...    8452     19102 2020-09-26
# 210         NaN  1621260     1391198  ...    6364     14925 2020-09-27
# 211         NaN  1653275     1150048  ...    6328     42707 2020-09-28
# 212         NaN  1714357     1246156  ...    6133     43964 2020-09-29
# 213         NaN  1773708     1331020  ...    6487     43867 2020-09-30
#
# [214 rows x 17 columns]

# %% [markdown]
# # Plot daily visitors 2019 vs 2020

# %%
visit_2019_df = pd.read_csv('drive/My Drive/SafeGraph/daily_visits_2019_ext.csv')
visit_2020_df = pd.read_csv('drive/My Drive/SafeGraph/daily_visits_2020_ext.csv')

# %%
visit_2020_df.sum(axis=1)
# Out:
# 0      8835045
# 1      8612180
# 2      8612951
# 3      8330270
# 4      8845101
#         ...
# 209    6057620
# 210    4861589
# 211    4594750
# 212    4798768
# 213    4993985
# Length: 214, dtype: int64

# %%
plt.plot(visit_2019_df.sum(axis=1))
plt.plot(visit_2020_df.sum(axis=1))
plt.title('Total visits')
plt.ylim(bottom = 0)
# Out:
# (0.0, 11093322.7)

# %%
#len(place_types)
#place_types = [key for key in places_ext['place_type'].value_counts().keys()]
place_types
# Out:
# ['other',
#  'restaurant',
#  'clinic',
#  'recreation',
#  'store',
#  'worship',
#  'pharmacy',
#  'daycare',
#  'supermarket',
#  'convenience store',
#  'long term care',
#  'library',
#  'bar',
#  'museum',
#  'hospital']

# %%
fig, axs = plt.subplots(5, 3, figsize=(17, 25), sharex='col')

for row in range(0,5):
  for col in range(0,3):
    idx = 3*row + col
    if idx < len(place_types):
      axs[row, col].plot(visit_2019_df[place_types[idx]], '-', label = '2019')
      axs[row, col].plot(visit_2020_df[place_types[idx]], '-', label = '2020')
      axs[row, col].set_title(place_types[idx])
      axs[row, col].set_ylim(bottom = 0)


#  ax[ii].legend()
#  ax[ii].xlabel('Days since March 1st')
#  ax[ii].ylabel('Total number of visits')
#  ax[ii].title(place_types[ii])

# %% [markdown]
# # Join `places_ext` with the original places to retrieve the NAICS code

# %%
large_places = pd.read_csv("drive/My Drive/SafeGraph/places/core_places_IL.csv")
large_places.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132091 entries, 0 to 132090
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 132091 non-null  int64
#  1   safegraph_place_id         132091 non-null  object
#  2   parent_safegraph_place_id  18968 non-null   object
#  3   location_name              132091 non-null  object
#  4   safegraph_brand_ids        30605 non-null   object
#  5   brands                     30605 non-null   object
#  6   top_category               130284 non-null  object
#  7   sub_category               130284 non-null  object
#  8   naics_code                 130284 non-null  float64
#  9   latitude                   132091 non-null  float64
#  10  longitude                  132091 non-null  float64
#  11  street_address             132091 non-null  object
#  12  city                       132091 non-null  object
#  13  region                     132091 non-null  object
#  14  postal_code                132091 non-null  int64
#  15  iso_country_code           132091 non-null  object
#  16  phone_number               101471 non-null  float64
#  17  open_hours                 69805 non-null   object
#  18  category_tags              19974 non-null   object
#  19  GEOID                      132091 non-null  int64
# dtypes: float64(4), int64(3), object(13)
# memory usage: 20.2+ MB

# %%
places_ext = places_ext.merge(large_places, on='safegraph_place_id')
places_ext['naics_2digit'] = places_ext['naics_code'].astype(str).apply(lambda x: x[0:2])
places_ext['naics_3digit'] = places_ext['naics_code'].astype(str).apply(lambda x: x[0:3])

# %%
places_visit_counts = patterns_2019[['safegraph_place_id', 'raw_visit_counts']].groupby('safegraph_place_id').sum()
places_ext = places_ext.merge(places_visit_counts, on='safegraph_place_id', how='left')

# %%
places_ext.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95834 entries, 0 to 95833
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   safegraph_place_id         95834 non-null  object
#  1   place_type                 95834 non-null  object
#  2   Unnamed: 0                 95834 non-null  int64
#  3   parent_safegraph_place_id  10417 non-null  object
#  4   location_name              95834 non-null  object
#  5   safegraph_brand_ids        21899 non-null  object
#  6   brands                     21899 non-null  object
#  7   top_category               95551 non-null  object
#  8   sub_category               95551 non-null  object
#  9   naics_code                 95551 non-null  float64
#  10  latitude                   95834 non-null  float64
#  11  longitude                  95834 non-null  float64
#  12  street_address             95834 non-null  object
#  13  city                       95834 non-null  object
#  14  region                     95834 non-null  object
#  15  postal_code                95834 non-null  int64
#  16  iso_country_code           95834 non-null  object
#  17  phone_number               73983 non-null  float64
#  18  open_hours                 48611 non-null  object
#  19  category_tags              18641 non-null  object
#  20  GEOID                      95834 non-null  int64
#  21  naics_2digit               95834 non-null  object
#  22  naics_3digit               95834 non-null  object
#  23  raw_visit_counts           80155 non-null  float64
# dtypes: float64(5), int64(3), object(16)
# memory usage: 18.3+ MB

# %%
summ_2digits = places_ext[['place_type', 'naics_2digit', 'safegraph_place_id', 'raw_visit_counts']].groupby(['place_type', 'naics_2digit']).agg({'safegraph_place_id':'count', 'raw_visit_counts':'sum'})
summ_3digits = places_ext[['place_type', 'naics_3digit', 'safegraph_place_id', 'raw_visit_counts']].groupby(['place_type', 'naics_3digit']).agg({'safegraph_place_id':'count', 'raw_visit_counts':'sum'})

# %%
summ_2digits.to_csv("drive/My Drive/SafeGraph/summ_by_naics_2digits.csv")

# %%
summ_3digits.to_csv("drive/My Drive/SafeGraph/summ_by_naics_3digits.csv")
