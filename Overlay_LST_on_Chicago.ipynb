# %% [markdown]
# <a href="https://colab.research.google.com/github/kywch/geo-colab/blob/master/Overlay_LST_on_Chicago.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading https://files.pythonhosted.org/packages/cc/1c/0f36885ac5864b8ad75f167ca1d403666a5f0c3b2ea8ad3366c98a628e99/rasterio-1.1.7-cp36-cp36m-manylinux1_x86_64.whl (18.1MB)
#      |████████████████████████████████| 18.1MB 1.5MB/s
# Collecting click-plugins
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Collecting affine
#   Downloading https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from rasterio) (20.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.18.5)
# Collecting snuggs>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from rasterio) (7.1.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.6/dist-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# Installing collected packages: click-plugins, affine, snuggs, cligj, rasterio
# Successfully installed affine-2.3.0 click-plugins-1.1.1 cligj-0.5.0 rasterio-1.1.7 snuggs-1.4.7

# %%
# Import necessary packages
import os, os.path
from glob import glob
from shutil import copyfile

import folium
from folium import plugins
import rasterio as rio
from rasterio.warp import calculate_default_transform, reproject, Resampling

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors as colors

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
files = glob("drive/My Drive/SatTemp/*_LST_*")
print(files)
# Out:
# ['drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010100.001.20201001084921.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010000.001.20201001083642.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010600.001.20201001095644.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010200.001.20201001090223.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010500.001.20201001094243.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010900.001.20201001104034.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010700.001.20201001101112.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010300.001.20201001091528.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010400.001.20201001092901.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010800.001.20201001102538.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011400.001.20201001115905.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011000.001.20201001105542.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011600.001.20201001123220.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011500.001.20201001121530.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011100.001.20201001111111.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011200.001.20201001112641.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011300.001.20201001114247.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906012000.001.20201001134155.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011700.001.20201001124928.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906012200.001.20201001141758.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011900.001.20201001132407.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906012300.001.20201001143614.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906012100.001.20201001135953.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011800.001.20201001130642.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020000.001.20201001164532.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020200.001.20201001171114.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020100.001.20201001165816.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020300.001.20201001172433.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020400.001.20201001173801.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020500.001.20201001175139.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021300.001.20201001194828.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020700.001.20201001181936.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020600.001.20201001180526.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021100.001.20201001191755.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020800.001.20201001183353.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906020900.001.20201001184814.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021000.001.20201001190249.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021200.001.20201001193258.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021800.001.20201001211001.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021500.001.20201001201958.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021600.001.20201001203614.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021400.001.20201001200409.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906022000.001.20201001214428.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021700.001.20201001205256.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906021900.001.20201001212712.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906022200.001.20201001222037.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906022300.001.20201001223854.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906022100.001.20201001220228.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906030000.001.20201001225734.tif', 'drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906030400.001.20201002001457.tif', ...

# %%
if not os.path.exists('geotiff'):
  os.mkdir('geotiff')

# %%
# copy these files from Google Drive to colab disk
for f in files:
  print(f)
  copyfile(f, 'geotiff/' + os.path.basename(f))
# Out:
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010100.001.20201001084921.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010000.001.20201001083642.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010600.001.20201001095644.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010200.001.20201001090223.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010500.001.20201001094243.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010900.001.20201001104034.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010700.001.20201001101112.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010300.001.20201001091528.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010400.001.20201001092901.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906010800.001.20201001102538.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011400.001.20201001115905.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011000.001.20201001105542.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011600.001.20201001123220.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906011500.001.20201001121530.tif
# drive/My Drive/SatTemp/MuSLI_LST_Chicago.201906
Chicago.201906030700.001.20201002011607.tif', 'geotiff/MuSLI_LST_Chicago.201906030800.001.20201002013646.tif', 'geotiff/MuSLI_LST_Chicago.201906030900.001.20201002015743.tif', 'geotiff/MuSLI_LST_Chicago.201906031000.001.20201002021847.tif', 'geotiff/MuSLI_LST_Chicago.201906031100.001.20201002024035.tif', 'geotiff/MuSLI_LST_Chicago.201906031200.001.20201002030158.tif', 'geotiff/MuSLI_LST_Chicago.2019060 ...

# %%
lst_files[10].split('.')[1][7] + '_' + lst_files[10].split('.')[1][8:10]
# Out:
# '1_10'

# %%
boundary = {}
raster = {}
nodata = {}
src_crs = {}

for file in lst_files:
  key = file.split('.')[1][7] + '_' + file.split('.')[1][8:10]
  with rio.open(file) as src:
    boundary[key] = src.bounds
    raster[key] = src.read()
    nodata[key] = src.nodata
    src_crs[key] = src.crs

# %%
#boundary
#nodata
#src_crs

# %%
clat = (boundary[key].bottom + boundary[key].top)/2
clon = (boundary[key].left + boundary[key].right)/2
print(key, clat, clon)
# Out:
# 3_23 41.80790530358678 -87.78840479684908

# %%
import pandas as pd

# create a wide-form pandas
raster_df = pd.DataFrame()

# %%
for key in raster.keys():
  raster_df[key] = raster[key].ravel()

raster_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652120 entries, 0 to 652119
# Data columns (total 72 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   1_00    652120 non-null  float64
#  1   1_01    652120 non-null  float64
#  2   1_02    652120 non-null  float64
#  3   1_03    652120 non-null  float64
#  4   1_04    652120 non-null  float64
#  5   1_05    652120 non-null  float64
#  6   1_06    652120 non-null  float64
#  7   1_07    652120 non-null  float64
#  8   1_08    652120 non-null  float64
#  9   1_09    652120 non-null  float64
#  10  1_10    652120 non-null  float64
#  11  1_11    652120 non-null  float64
#  12  1_12    652120 non-null  float64
#  13  1_13    632590 non-null  float64
#  14  1_14    538919 non-null  float64
#  15  1_15    593323 non-null  float64
#  16  1_16    642421 non-null  float64
#  17  1_17    652120 non-null  float64
#  18  1_18    652120 non-null  float64
#  19  1_19    629286 non-null  float64
#  20  1_20    247209 non-null  float64
#  21  1_21    338519 non-null  float64
#  22  1_22    177669 non-null  float64
#  23  1_23    63537 non-null   float64
#  24  2_00    145617 non-null  float64
#  25  2_01    445548 non-null  float64
#  26  2_02    573086 non-null  float64
#  27  2_03    652120 non-null  float64
#  28  2_04    652120 non-null  float64
#  29  2_05    652120 non-null  float64
#  30  2_06    652120 non-null  float64
#  31  2_07    652120 non-null  float64
#  32  2_08    652120 non-null  float64
#  33  2_09    652120 non-null  float64
#  34  2_10    652120 non-null  float64
#  35  2_11    652120 non-null  float64
#  36  2_12    652120 non-null  float64
#  37  2_13    652120 non-null  float64
#  38  2_14    652120 non-null  float64
#  39  2_15    652120 non-null  float64
#  40  2_16    652120 non-null  float64
#  41  2_17    652120 non-null  float64
#  42  2_18    652120 non-null  float64
#  43  2_19    652120 non-null  float64
#  44  2_20    652120 non-null  float64
#  45  2_21    652120 non-null  float64
#  46  2_22    652120 non-null  float64
#  47  2_23    652120 non-null  float64
#  48  3_00    652120 non-null  float64
#  49  3_01    652120 non-null  float64
#  50  3_02    652120 non-null  float64
#  51  3_03    652120 non-null  float64
#  52  3_04    652120 non-null  float64
#  53  3_05    652120 non-null  float64
#  54  3_06    652120 non-null  float64
#  55  3_07    652120 non-null  float64
#  56  3_08    652120 non-null  float64
#  57  3_09    652120 non-null  float64
#  58  3_10    652120 non-null  float64
#  59  3_11    652120 non-null  float64
#  60  3_12    652120 non-null  float64
#  61  3_13    652120 non-null  float64
#  62  3_14    652120 non-null  float64
#  63  3_15    652120 non-null  float64
#  64  3_16    652120 non-null  float64
#  65  3_17    652120 non-null  float64
#  66  3_18    652120 non-null  float64
#  67  3_19    652120 non-null  float64
#  68  3_20    652120 non-null  float64
#  69  3_21    652120 non-null  float64
#  70  3_22    652120 non-null  float64
#  71  3_23    652120 non-null  float64
# dtypes: float64(72)
# memory usage: 358.2 MB

# %%
import seaborn as sns

fig, axs = plt.subplots(nrows=3, figsize=(24,16))

sns.violinplot(data=raster_df.iloc[:,0:24], ax=axs[0])
sns.violinplot(data=raster_df.iloc[:,24:48], ax=axs[1])
sns.violinplot(data=raster_df.iloc[:,48:72], ax=axs[2])

# %%
key = '2_11'
tmin = np.floor(np.nanmin(raster[key]))
tmax = np.ceil(np.nanmax(raster[key]))
plt.hist(raster[key].ravel(), bins=30, range=(tmin, tmax))
plt.show()

# %%
def mapvalue2color(value, cmap): 
    """
    Map a pixel value of image to a color in the rgba format. 
    As a special case, nans will be mapped totally transparent.
    
    Inputs
        -- value - pixel value of image, could be np.nan
        -- cmap - a linear colormap from branca.colormap.linear
    Output
        -- a color value in the rgba format (r, g, b, a)    
    """
    if np.isnan(value):
        return (1, 0, 0, 0)
    else:
        return colors.to_rgba(cmap(value), 0.7)

# %%
#boundary
#src.bounds
#img.shape

# %%
uchicago_loc = [41.7886, -87.5987]

# Create a map using the Map() function and the coordinates for Chicago, IL
m = folium.Map(location=uchicago_loc, tiles='Stamen Terrain', zoom_start=12)

key = '2_11'

# adjust the color map
import branca.colormap as cm
tmin = np.floor(np.nanmin(raster[key]))
tmax = np.ceil(np.nanmax(raster[key]))
colormap = cm.linear.RdBu_11.scale(tmin, tmax)
print('Colormap range: ', tmin, tmax)

# overlay the raster
folium.raster_layers.ImageOverlay(
    image = raster[key][0],
    name = key,
    opacity = 0.7,
    pixelated = True,
    bounds = [[boundary[key].bottom, boundary[key].left], [boundary[key].top, boundary[key].right]],
    colormap= lambda value: mapvalue2color(value, colormap)
).add_to(m)

folium.Marker(uchicago_loc, popup='UChicago').add_to(m)

folium.LayerControl().add_to(m)
colormap.caption = 'MuSLI_LST'
m.add_child(colormap)

m
# Out:
# Colormap range:  278.0 291.0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
